# %% [markdown]
# # Константы

# %%
API_KEY = "" # OPEN_AI_API_KEY

TRANSCRIBED_FOLDER_PATH = '/content/drive/My Drive/ВКР/multiple-talk-2024-10-27/transcribed/'
FULLY_TRANSCRIBED_FOLDER_PATH = '/content/drive/My Drive/ВКР/multiple-talk-2024-10-27/fully_transcribed/'

WINDOWS_1251_ENCODING = 'windows-1251'
UTF8_ENCODING = 'utf-8'

AUDIO_FILE_FOLDER_PATH = '/content/drive/My Drive/ВКР/multiple-talk-2024-10-27/'
BASE_TRANSCRIBED_TEXT_PATH = '/content/drive/My Drive/ВКР/text/'

DIARIZED_OUTPUT_FOLDER_PATH = '/content/drive/My Drive/ВКР/multiple-talk-2024-10-27/diarized/'
OPEN_API_TRNSCRIBE_URL = 'https://api.openai.com/v1/audio/transcriptions'
OPEN_API_AUTH_HEADERS = headers = { 'Authorization': f'Bearer {API_KEY}' }

# %% [markdown]
# # Функции для работы с Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import auth
from googleapiclient.discovery import build
import requests
from googleapiclient.http import MediaIoBaseDownload
from google.colab import auth
import io

auth.authenticate_user()
drive_service = build('drive', 'v3')

def get_folder_id(folder_path):
    folder_name = folder_path.split('/')[-1]
    parent_folder_id = None

    folders = folder_path.split('/')[:-1]

    for folder in folders:
        query = f"mimeType='application/vnd.google-apps.folder' and name='{folder}'"
        if parent_folder_id:
            query += f" and '{parent_folder_id}' in parents"

        results = drive_service.files().list(q=query, pageSize=10, fields="files(id, name)").execute()
        items = results.get('files', [])

        if items:
            parent_folder_id = items[0]['id']
    return parent_folder_id

def list_files_in_folder(folder_id):
    results = drive_service.files().list(
        q=f"'{folder_id}' in parents",
        fields="nextPageToken, files(id, name)",
        pageSize=1000
    ).execute()
    items = results.get('files', [])

    return items

def download_audio_file(file_id):
    request = drive_service.files().get_media(fileId=file_id)
    file_metadata = request.execute()

    downloaded_file = io.BytesIO()
    downloader = MediaIoBaseDownload(downloaded_file, request)

    done = False
    while done is False:
        status, done = downloader.next_chunk()
        print(f"Download {int(status.progress() * 100)}%.")
    return downloaded_file

def save_text_to_drive(file_name, file_text):
    with open(file_name, 'w', encoding=WINDOWS_1251_ENCODING) as file:
        file.write(json.dumps(file_text, indent=4, ensure_ascii=False))

def get_audio_session_id(file_name):
    session_name = None
    is_session_name = False
    for part in file_name.split('_'):
        if is_session_name:
            session_name = part
            break
        if part == 'session':
            is_session_name = True

    if session_name == None:
        raise ValueError("Не удалось получить имя сессии диалога")
    return session_name

# %% [markdown]
# # Функции для работы с Open AI

# %%
import requests
import openai
import io
import json

def transcribe_audio(file_id, session_id):

    downloaded_file = download_audio_file(file_id)
    downloaded_file.seek(0)

    files = {
        'file': ('audio_file.wav', downloaded_file, 'audio/mpeg'),
        'model': (None, 'whisper-1'),
        'language': (None, 'ru'),
        'response_format': (None, 'verbose_json')
    }

    response = requests.post(OPEN_API_TRNSCRIBE_URL, headers=OPEN_API_AUTH_HEADERS, files=files)

    new_file_name = f"{TRANSCRIBED_FOLDER_PATH}{session_id}.txt"
    save_text_to_drive(new_file_name, response.json())

# %% [markdown]
# # Процесс транскрибации

# %%
def read_all_audio_files():
    loaded_files = []

    for i in range(1, 8):
        folder_path = f'{AUDIO_FILE_FOLDER_PATH}{i}/'
        folder_id = get_folder_id(folder_path)

        if folder_id:
            files = list_files_in_folder(folder_id)
            if len(files) < 1:
                continue
            print("Файлы в папке:")
            loaded_files.extend(files)
            for file in files:
                print(f"ID: {file['id']}, Имя: {file['name']}")
        else:
            raise ValueError('Папка не найдена')
    return loaded_files

# %% [markdown]
# Считываем все файлы в один список

# %%
loaded_files = read_all_audio_files()
if len(loaded_files) < 1:
    raise ValueError('Не найдены аудил файлы')

total = len(loaded_files)

# %% [markdown]
# Транскрибация файлов

# %%
counter = 0
for file in loaded_files:
    session_part = get_audio_session_id(file['name'])
    try:
        transcribe_audio(file['id'], session_part)
    except Exception as e:
        print(f"Возникла ошибка: {e}")
    counter += 1
    print(f'Обработано: {counter} из {total}')

# %% [markdown]
# # Оценка транскрибации

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
import json
import re

def preprocess_base_text(text):
    # Убрать даты
    timestamp_pattern = r'\b\d{1,2}:\d{2}:\d{2}\b'

    cleaned_text = re.sub(timestamp_pattern, '', text)
    # Убрать лишние символы и пробелы
    cleaned_text = re.sub(r'\s+', ' ', cleaned_text).strip()
    cleaned_text = re.sub(r'[^\w\s]', '', cleaned_text)
    return ' '.join(cleaned_text.strip().lower().split())

def preprocess_transcribed_text(text):
    # Преобразовать в json
    data = json.loads(text)
    # Достать транскрибированный текст
    diarized_text = data.get("text")
    # Удалить лишние сиволы и пробелы
    cleaned_text = re.sub(r'[^\w\s]', '', diarized_text)
    return ' '.join(cleaned_text.strip().lower().split())

def calculate_metrics(reference, hypothesis):
    reference_words = reference.split()
    hypothesis_words = hypothesis.split()

    reference_set = set(reference_words)
    hypothesis_set = set(hypothesis_words)

    true_positives = len(reference_set.intersection(hypothesis_set))
    false_positives = len(hypothesis_set - reference_set)
    false_negatives = len(reference_set - hypothesis_set)

    precision = true_positives / (true_positives + false_positives) if (true_positives + false_positives) > 0 else 0
    recall = true_positives / (true_positives + false_negatives) if (true_positives + false_negatives) > 0 else 0
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

    return precision, recall, f1

def evaluate_text(reference_text, hypothesis_text):
    result_list = []
    print(reference_text)

    precision, recall, f1 = calculate_metrics(reference_text, hypothesis_text)
    result_list.append(f'{precision:.2f}')
    result_list.append(f'{recall:.2f}')
    result_list.append(f'{f1:.2f}')
    return result_list

def get_all_files(folder_path):
    loaded_files = []
    folder_id = get_folder_id(folder_path)

    if folder_id:
        files = list_files_in_folder(folder_id)
        print(f'{len(files)} files in the folder')
        loaded_files.extend(files)
    else:
        raise ValueError("Папка не найдена")
    return loaded_files

def read_file_text(file_id, encoding):
    request = drive_service.files().get_media(fileId=file_id)
    response = request.execute()
    return response.decode(encoding)

# %% [markdown]
# Загрузка эталонных и транскрибированных текстов

# %%
transcribed_files = get_all_files(TRANSCRIBED_FOLDER_PATH)
base_files = get_all_files(BASE_TRANSCRIBED_TEXT_PATH)
# Out:
# 317 files in the folder
# 204 files in the folder

# %% [markdown]
# Оценка качества транскрибации

# %%
import pandas as pd

columns = ['Имя файла', 'Точность', 'Полнота', 'F1-мера']
df = pd.DataFrame(columns=columns)

for test_file in transcribed_files:
    try:
        transcribed_text = preprocess_transcribed_text(read_file_text(test_file['id'], WINDOWS_1251_ENCODING))

        base_text_file = None
        for base_file in base_files:
            if base_file['name'] == test_file['name'].replace('Копия ', ''):
                base_text_file = base_file
                break

        if base_text_file == None:
            print(f'Не найден эталонный текст для {test_file["name"]}')
            continue

        base_text = preprocess_base_text(read_file_text(base_text_file['id'], UTF8_ENCODING))

        precision, recall, f1 = calculate_metrics(base_text, transcribed_text)

        result_row = {'Имя файла': test_file['name'],
                      'Точность': f'{precision:.2f}',
                      'Полнота': f'{recall:.2f}',
                      'F1-мера': f'{f1:.2f}'}

        df = pd.concat([df, pd.DataFrame([result_row])], ignore_index=True)
    except Exception as e:
        print(f"Ошибка получения файла {e}")

# %% [markdown]
# Вывод результатов оценки качества транскрибации

# %%
df
df[df['Точность'].astype(float) > 0]
precision = df['Точность'].astype(float).median()
df[df['Полнота'].astype(float) > 0]
recall = df['Полнота'].astype(float).median()
df[df['F1-мера'].astype(float) > 0]
f1 = df['F1-мера'].astype(float).median()
print(f'Точность: {precision}')
print(f'Полнота: {recall}')
print(f'F1-мера: {f1}')
# Out:
# Точность: 0.8
# Полнота: 0.74
# F1-мера: 0.75

# %% [markdown]
# При анализе транскрибации на основе представленных метрик (точность, полнота и F1-мера) получились следущие значения:
#
# Общие характеристики метрик:
#
# *   Точность (Precision): 0.8
# *   Полнота (Recall): 0.74
# *   F1-мера: 0.75
#
# **Заключение:**
#
# В целом, результаты проверки качества транскрибации показывают, что модель демонстрирует хорошие показатели точности.

# %% [markdown]
# # Диаризация

# %%
! pip install pydub
! pip install pyannote.audio
! pip install SpeechRecognition
! pip install -qq https://github.com/pyannote/pyannote-audio/archive/refs/heads/develop.zip

# %%
from pyannote.audio import Pipeline
import torch

pipeline = Pipeline.from_pretrained("pyannote/speaker-diarization@2.1", use_auth_token="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")
pipeline.to(torch.device("cuda"))
# Out:
# config.yaml:   0%|          | 0.00/500 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/17.7M [00:00<?, ?B/s]
# INFO:pytorch_lightning.utilities.migration.utils:Lightning automatically upgraded your loaded checkpoint from v1.5.4 to v2.4.0. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint ../root/.cache/torch/pyannote/models--pyannote--segmentation/snapshots/c4c8ceafcbb3a7a280c2d357aee9fbc9b0be7f9b/pytorch_model.bin`
# Model was trained with pyannote.audio 0.0.1, yours is 3.3.2. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.10.0+cu102, yours is 2.5.1+cu121. Bad things might happen unless you revert torch to 1.x.
# hyperparams.yaml:   0%|          | 0.00/1.92k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/speechbrain/utils/autocast.py:68: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   wrapped_fwd = torch.cuda.amp.custom_fwd(fwd, cast_inputs=cast_inputs)
# embedding_model.ckpt:   0%|          | 0.00/83.3M [00:00<?, ?B/s]
# mean_var_norm_emb.ckpt:   0%|          | 0.00/1.92k [00:00<?, ?B/s]
# classifier.ckpt:   0%|          | 0.00/5.53M [00:00<?, ?B/s]
# label_encoder.txt:   0%|          | 0.00/129k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/speechbrain/utils/checkpoints.py:200: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(path, map_location=device)
# /usr/local/lib/python3.10/dist-packages/speechbrain/processing/features.py:1311: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   stats = torch.load(path, map_location=device)

# %%
def convert_to_wav(mp3_audio_data):
    print("Конвертация файла в wav формат")

    audio = mp3_audio_data

    mp3_audio = AudioSegment.from_file(audio, format="mp3")

    output_file = "output.wav"

    mp3_audio.export(output_file, format="wav")

    print(f'Файл успешно сконвертирован в WAV: {output_file}')
    return output_file

# %%
class DiarizedText:
    def __init__(self, speaker, start, end, text):
        self.name = speaker
        self.start = start
        self.end = end
        self.text = text

    def to_string(self):
        print(f'{self.name}: {self.text}')

    def full_to_string(self):
        return f'{self.name}: {self.start} - {self.end}. text : {self.text}'

    def to_dict(self):
        return {
            'name': self.name,
            'start': self.start,
            'end': self.end,
            'text': self.text
        }

class DiarizedTextEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, DiarizedText):
            return {
                'name': obj.name,
                'start': obj.start,
                'end': obj.end,
                'text': obj.text
            }
        return json.JSONEncoder.default(self, obj)

# %% [markdown]
# # Процесс диаризации

# %%
loaded_files = read_all_audio_files()

# %%
import json
from pydub import AudioSegment

for file in loaded_files:
    print(f'Диаризация {file["name"]}')
    session_name = get_audio_session_id(file['name'])

    downloaded_file = download_audio_file(file['id'])
    downloaded_file.seek(0)

    output_path = convert_to_wav(downloaded_file)

    diarization = pipeline(output_path)
    diarized_list = []

    for turn, _, speaker in diarization.itertracks(yield_label=True):
        diarized_list.append(DiarizedText(speaker, f'{turn.start:.1f}', f'{turn.end:.1f}', ''))
    diarized_texts_dict = [dt.to_dict() for dt in diarized_list]

    json_string = json.dumps(diarized_texts_dict, ensure_ascii=False, indent=4)

    save_text_to_drive(f'{DIARIZED_OUTPUT_FOLDER_PATH}{session_name}.txt', json_string)

# %% [markdown]
# Сопоставление результатов диаризации и транскрибации

# %%
transcribed_files = get_all_files(TRANSCRIBED_FOLDER_PATH)
diarized_files = get_all_files(DIARIZED_OUTPUT_FOLDER_PATH)
# Out:
# 317 files in the folder
# 261 files in the folder

# %%
def get_diarized_file(file_name):
    pared_diarized_file = None
    for diarized_file in diarized_files:
        if diarized_file['name'] == file_name:
            pared_diarized_file = diarized_file
            break

    return pared_diarized_file
count = 0
for transcribed_file in transcribed_files:
    pared_diarized_file = get_diarized_file(transcribed_file['name'])
    if pared_diarized_file == None:
          print(f'Не найдена диаризация дла {transcribed_file["name"]}')
          continue

    transcribed_json = read_file_text(transcribed_file['id'], WINDOWS_1251_ENCODING)
    diarized_json = read_file_text(pared_diarized_file['id'], UTF8_ENCODING)

    transcribed_data = json.loads(transcribed_json)
    diarized_data = json.loads(diarized_json.replace('\\n', '').replace('\\\"', '\"')[1:-1])
    parsed_segments = []
    diarized_rows = []
    for segment in transcribed_data['segments']:
        parsed_segments.append(DiarizedText('', segment['start'], segment['end'], segment['text']))

    for entry in diarized_data:
        diarized_rows.append(DiarizedText(entry['name'], entry['start'], entry['end'], ''))

    speakers = []
    prev_speaker = None

    processed_speakers = []
    processed_segments = []

    for speaker in diarized_rows:
        processed = False
        for segment in parsed_segments:
            if segment in processed_segments:
                continue
            if float(speaker.start) >= float(segment.start) and float(speaker.end) < float(segment.end):
                speakers.append(DiarizedText(speaker.name, speaker.start, speaker.end, segment.text))
                processed_segments.append(segment)
                processed = True
                break

        if processed:
            continue

        for segment in parsed_segments:
            if segment in processed_segments:
                continue
            if float(speaker.start) > float(segment.start):
                speakers.append(DiarizedText(speaker.name, speaker.start, speaker.end, segment.text))
                processed_segments.append(segment)
                processed_speakers.append(speaker)

    for s in speakers:
        print(s.full_to_string())
    json_string = json.dumps(speakers, cls=DiarizedTextEncoder, indent=4, ensure_ascii=False)
    save_text_to_drive(f'{FULLY_TRANSCRIBED_FOLDER_PATH}{transcribed_file["name"]}', json_string)
    count += 1
    print(count)
# Out:
# 76
# 87
# : 0.0 - 5.0. text :  Алло. Как вы?
# : 5.0 - 9.0. text :  Займись частным распытом. У вас к нему срочный вопрос?
# : 9.0 - 11.0. text :  Очень срочный.
# : 11.0 - 21.0. text :  Пока что абонент вне сети, но я записала для него ваш ответ. Попросите его вам перезвонить, когда он вернется в сеть.
# : 22.0 - 35.0. text :  Да, конечно, перезвоните. Я по поводу возможности встречи онлайн моего руководства с вами. Тема встречи это верификация жребщиков без участия ваших сотрудников.
# : 35.0 - 45.0. text :  Да я не договорил, блин. Тема встречи это верификация жребщиков без участия ваших сотрудников. Как мы сделали это в Манимейде, Лайнзайме, Веббанкире и других средствах.
# : 45.0 - 49.0. text :  Подскажите, вы звоните по личному или по деловому вопросу?
# : 49.0 - 56.0. text :  Вот этот вопрос можно передать добителю.
# : 56.0 - 62.0. text :  Может быть передать абоненту в какое время можно вам перезвонить?
# : 62.0 - 67.0. text :  Скажите погромче, я вас не услышала.
# : 67.0 - 71.0. text :  Повторите погромче.
# : 71.0 - 74.0. text :  Алло, вы тут?
# : 74.0 - 78.0. text :  Извините, меня слышно?
# : 78.0 - 84.0. text :  А может ли абонент связаться с вами по номеру, с которого вы звоните?
# : 84.0 - 87.0. text :  Алло, вы тут?
# : 87.0 - 92.0. text :  Скажите погромче, я вас не услышала.
# : 92.0 - 96.0. text :  А повторите погромче.
# : 96.0 - 100.0. text :  Скажите еще раз, пожалуйста.
# : 100.0 - 106.0. text :  Уточните, вы знакомы с абонентом или мне представить вас?
# : 106.0 - 111.0. text :  Скажите погромче, я вас не услышала.
# : 111.0 - 115.0. text :  Скажите еще раз, пожалуйста.
# : 115.0 - 119.0. text :  Извините, меня слышно?
# : 119.0 - 123.0. text :  А не могли бы вы повторить?
# : 123.0 - 129.0. text :  Подскажите, вы звоните по личному или по деловому вопросу?
# : 129.0 - 134.0. text :  Я не расслышала, повторите, пожалуйста.
# : 134.0 - 138.0. text :  Извините, меня слышно?
# : 138.0 - 142.0. text :  Не расслышала, что вы сказали?
# : 142.0 - 147.0. text :  А не могли бы вы повторить?
# : 147.0 - 152.0. text :  Может быть передать абоненту, в какое время можно вам перезвонить?
# : 152.0 - 157.0. text :  Я не расслышала, повторите, пожалуйста.
# : 157.0 - 161.0. text :  А повторите погромче.
# : 161.0 - 164.0. text :  Алло, вы тут?
# : 164.0 - 168.0. text :  Скажите еще раз, пожалуйста.
# : 168.0 - 174.0. text :  А может ли абонент связаться с вами по номеру, с которого вы звоните?
# : 174.0 - 177.0. text :  А повторите погромче.
# : 177.0 - 181.0. text :  Алло, вы тут?
# : 181.0 - 185.0. text :  Скажите погромче, я вас не услышала.
# : 185.0 - 189.0. text :  Скажите еще раз, пожалуйста.
# : 189.0 - 195.0. text :  Уточните, вы знакомы с абонентом или мне представить вас?
# : 195.0 - 199.0. text :  Алло, вы тут?
# : 199.0 - 203.0. text :  Скажите погромче, я вас не услышала.
# : 203.0 - 207.0. text :  А повторите погромче.
# : 207.0 - 212.0. text :  Я не расслышала, повторите, пожалуйста.
# : 212.0 - 218.0. text :  Подскажите, вы звоните по личному или по деловому вопросу?
# : 218.0 - 222.0. text :  Я не расслышала, что вы сказали?
# : 222.0 - 226.0. text :  Скажите еще раз, пожалуйста.
# : 226.0 - 231.0. text :  А не могли бы вы повторить?
# : 231.0 - 236.0. text :  Я не расслышала, повторите, пожалуйста.
# : 236.0 - 241.0. text :  Может быть передать абоненту, в какое время можно вам перезвонить?
# : 241.0 - 245.0. text :  А повторите погромче.
# : 245.0 - 249.0. text :  Скажите еще раз, пожалуйста.
# : 249.0 - 253.0. text :  Извините, меня слышно?
# : 253.0 - 257.0. text :  Не расслышала, что вы сказали?
# : 257.0 - 263.0. text :  А может ли абонент связаться с вами по номеру, с которого вы звоните?
# : 263.0 - 267.0. text :  А повторите погромче.
# : 267.0 - 271.0. text :  Я не расслышала, повторите, пожалуйста.
# : 271.0 - 275.0. text :  Не расслышала, что вы сказали?
# : 275.0 - 279.0. text :  Извините, меня слышно?
# : 279.0 - 285.0. text :  Уточните, вы знакомы с абонентом или мне представить вас?
# : 285.0 - 289.0. text :  А повторите погромче.
# : 289.0 - 293.0. text :  А повторите погромче, пожалуйста.
# : 293.0 - 296.0. text :  Алло, вы тут?
# : 296.0 - 300.0. text :  Не расслышала, что вы сказали?
# : 300.0 - 306.0. text :  Подскажите, вы звоните по личному или по деловому вопросу?
# : 306.0 - 311.0. text :  Скажите погромче, я вас не услышала.
# : 311.0 - 315.0. text :  Извините, меня слышно?
# : 315.0 - 319.0. text :  А повторите погромче, пожалуйста.
# : 319.0 - 324.0. text :  Я не расслышала, повторите, пожалуйста.
# : 324.0 - 330.0. text :  Может быть передать абоненту, в какое время можно вам перезвонить?
# : 330.0 - 335.0. text :  Скажите погромче, я вас не услышала.
# : 335.0 - 339.0. text :  Скажите еще раз, пожалуйста.
# : 339.0 - 343.0. text :  А повторите погромче, пожалуйста.
# : 343.0 - 347.0. text :  Извините, меня слышно?
# : 347.0 - 353.0. text :  А может ли абонент связаться с вами по номеру, с которого вы звоните?
# : 353.0 - 357.0. text :  Не расслышала, что вы сказали?
# : 357.0 - 361.0. text :  Скажите еще раз, пожалуйста.
# __________
# SPEAKER_00: 1.3 - 1.7. text :
# SPEAKER_02: 3.4 - 3.9. text :
# SPEAKER_02: 4.9 - 5.5. text :
# SPEAKER_01: 5.0 - 9.1. text :
# SPEAKER_02: 10.2 - 11.1. text :
# SPEAKER_01: 13.6 - 21.3. text :
# SPEAKER_02: 22.7 - 28.9. text :
# SPEAKER_02: 29.5 - 33.8. text :
# SPEAKER_01: 32.2 - 34.9. text :
# SPEAKER_02: 35.7 - 46.7. text :
# SPEAKER_01: 45.2 - 49.0. text :
# SPEAKER_02: 49.8 - 51.6. text :
# SPEAKER_02: 52.2 - 53.1. text :
# SPEAKER_01: 57.4 - 60.8. text :
# SPEAKER_01: 63.2 - 65.6. text :
# SPEAKER_01: 67.8 - 69.2. text :
# SPEAKER_01: 71.4 - 72.4. text :
# SPEAKER_01: 74.6 - 76.4. text :
# SPEAKER_01: 78.5 - 82.2. text :
# SPEAKER_01: 84.4 - 85.5. text :
# SPEAKER_01: 87.8 - 90.3. text :
# SPEAKER_01: 92.5 - 93.8. text :
# SPEAKER_01: 96.0 - 97.8. text :
# SPEAKER_01: 100.0 - 103.8. text :
# SPEAKER_01: 106.2 - 108.7. text :
# SPEAKER_01: 110.8 - 112.6. text :
# SPEAKER_01: 114.7 - 116.6. text :
# SPEAKER_01: 119.1 - 121.0. text :
# SPEAKER_01: 123.2 - 127.0. text :
# SPEAKER_01: 129.1 - 131.8. text :
# SPEAKER_00: 129.3 - 129.9. text :
# SPEAKER_01: 133.9 - 135.8. text :
# SPEAKER_01: 137.9 - 140.1. text :
# SPEAKER_01: 142.5 - 144.5. text :
# SPEAKER_01: 146.8 - 150.3. text :
# SPEAKER_01: 152.4 - 155.1. text :
# SPEAKER_00: 152.7 - 153.2. text :
# SPEAKER_01: 157.3 - 158.6. text :
# SPEAKER_01: 160.8 - 161.9. text :
# SPEAKER_01: 164.1 - 165.9. text :
# SPEAKER_01: 168.0 - 171.8. text :
# SPEAKER_01: 173.9 - 175.3. text :
# SPEAKER_01: 177.5 - 178.6. text :
# SPEAKER_01: 180.9 - 183.4. text :
# SPEAKER_01: 185.5 - 187.3. text :
# SPEAKER_01: 189.5 - 193.4. text :
# SPEAKER_01: 195.5 - 196.7. text :
# SPEAKER_01: 199.0 - 201.5. text :
# SPEAKER_01: 203.6 - 205.0. text :
# SPEAKER_01: 207.1 - 209.8. text :
# SPEAKER_00: 207.4 - 207.9. text :
# SPEAKER_01: 212.0 - 215.7. text :
# SPEAKER_01: 217.9 - 220.0. text :
# SPEAKER_01: 222.2 - 224.0. text :
# SPEAKER_01: 226.5 - 228.5. text :
# SPEAKER_01: 230.7 - 233.4. text :
# SPEAKER_00: 230.9 - 231.4. text :
# SPEAKER_01: 235.6 - 239.1. text :
# SPEAKER_01: 241.2 - 242.6. text :
# SPEAKER_01: 244.8 - 246.6. text :
# SPEAKER_01: 248.7 - 250.6. text :
# SPEAKER_01: 252.7 - 254.8. text :
# SPEAKER_01: 256.9 - 260.6. text :
# SPEAKER_01: 262.8 - 264.2. text :
# SPEAKER_01: 266.4 - 269.1. text :
# SPEAKER_00: 266.6 - 267.1. text :
# SPEAKER_01: 271.2 - 273.4. text :
# SPEAKER_01: 275.5 - 277.3. text :
# SPEAKER_01: 279.4 - 283.3. text :
# SPEAKER_01: 285.5 - 286.9. text :
# SPEAKER_01: 289.1 - 291.2. text :
# SPEAKER_01: 293.3 - 294.4. text :
# SPEAKER_01: 296.6 - 298.8. text :
# SPEAKER_01: 300.9 - 304.6. text :
# SPEAKER_01: 307.0 - 309.4. text :
# SPEAKER_01: 311.5 - 313.4. text :
# SPEAKER_01: 315.6 - 317.6. text :
# SPEAKER_01: 319.8 - 322.5. text :
# SPEAKER_00: 320.1 - 320.5. text :
# SPEAKER_01: 324.7 - 328.2. text :
# SPEAKER_01: 330.5 - 333.0. text :
# SPEAKER_01: 335.1 - 336.9. text :
# SPEAKER_01: 339.1 - 341.2. text :
# SPEAKER_01: 343.3 - 345.1. text :
# SPEAKER_01: 347.2 - 350.9. text :
# SPEAKER_01: 353.1 - 355.2. text :
# SPEAKER_01: 357.4 - 359.2. text :
# SPEAKER_00: 1.3 - 1.7. text :  Алло. Как вы?
# SPEAKER_02: 10.2 - 11.1. text :  Займись частным распытом. У вас к нему срочный вопрос?
# SPEAKER_02: 10.2 - 11.1. text :  Очень срочный.
# SPEAKER_01: 13.6 - 21.3. text :  Пока что абонент вне сети, но я записала для него ваш ответ. Попросите его вам перезвонить, когда он вернется в сеть.
# SPEAKER_02: 22.7 - 28.9. text :  Да, конечно, перезвоните. Я по поводу возможности встречи онлайн моего руководства с вами. Тема встречи это верификация жребщиков без участия ваших сотрудников.
# SPEAKER_02: 35.7 - 46.7. text :  Да я не договорил, блин. Тема встречи это верификация жребщиков без участия ваших сотрудников. Как мы сделали это в Манимейде, Лайнзайме, Веббанкире и других средствах.
# SPEAKER_01: 45.2 - 49.0. text :  Подскажите, вы звоните по личному или по деловому вопросу?
# SPEAKER_02: 49.8 - 51.6. text :  Вот этот вопрос можно передать добителю.
# SPEAKER_01: 57.4 - 60.8. text :  Может быть передать абоненту в какое время можно вам перезвонить?
# SPEAKER_01: 63.2 - 65.6. text :  Скажите погромче, я вас не услышала.
# SPEAKER_01: 67.8 - 69.2. text :  Повторите погромче.
# SPEAKER_01: 71.4 - 72.4. text :  Алло, вы тут?
# SPEAKER_01: 74.6 - 76.4. text :  Извините, меня слышно?
# SPEAKER_01: 78.5 - 82.2. text :  А может ли абонент связаться с вами по номеру, с которого вы звоните?
# SPEAKER_01: 84.4 - 85.5. text :  Алло, вы тут?
# SPEAKER_01: 87.8 - 90.3. text :  Скажите погромче, я вас не услышала.
# SPEAKER_01: 92.5 - 93.8. text :  А повторите погромче.
# SPEAKER_01: 96.0 - 97.8. text :  Скажите еще раз, пожалуйста.
# SPEAKER_01: 100.0 - 103.8. text :  Уточните, вы знакомы с абонентом или мне представить вас?
# SPEAKER_01: 106.2 - 108.7. text :  Скажите погромче, я вас не услышала.
# SPEAKER_01: 114.7 - 116.6. text :  Скажите еще раз, пожалуйста.
# SPEAKER_01: 119.1 - 121.0. text :  А не могли бы вы повторить?
# SPEAKER_01: 123.2 - 127.0. text :  Подскажите, вы звоните по личному или по деловому вопросу?
# SPEAKER_01: 129.1 - 131.8. text :  Я не расслышала, повторите, пожалуйста.
# SPEAKER_00: 129.3 - 129.9. text :  Извините, меня слышно?
# SPEAKER_01: 137.9 - 140.1. text :  Извините, меня слышно?
# SPEAKER_01: 142.5 - 144.5. text :  А не могли бы вы повторить?
# SPEAKER_01: 146.8 - 150.3. text :  Не расслышала, что вы сказали?
# SPEAKER_01: 152.4 - 155.1. text :  Я не расслышала, повторите, пожалуйста.
# SPEAKER_00: 152.7 - 153.2. text :  Может быть передать абоненту, в какое время можно вам перезвонить?
# SPEAKER_01: 157.3 - 158.6. text :  А повторите погромче.
# SPEAKER_01: 164.1 - 165.9. text :  Скажите еще раз, пожалуйста.
# SPEAKER_01: 168.0 - 171.8. text :  А может ли абонент связаться с вами по номеру, с которого вы звоните?
# SPEAKER_01: 173.9 - 175.3. text :  Алло, вы тут?
# SPEAKER_01: 177.5 - 178.6. text :  Алло, вы тут?
# SPEAKER_01: 180.9 - 183.4. text :  А повторите погромче.
# SPEAKER_01: 185.5 - 187.3. text :  Скажите еще раз, пожалуйста.
# SPEAKER_01: 189.5 - 193.4. text :  Уточните, вы знакомы с абонентом или мне представить вас?
# SPEAKER_01: 195.5 - 196.7. text :  Алло, вы тут?
# SPEAKER_01: 199.0 - 201.5. text :  Скажите погромче, я вас не услышала.
# SPEAKER_01: 203.6 - 205.0. text :  А повторите погромче.
# SPEAKER_01: 207.1 - 209.8. text :  Я не расслышала, повторите, пожалуйста.
# SPEAKER_00: 207.4 - 207.9. text :  Скажите погромче, я вас не услышала.
# SPEAKER_01: 212.0 - 215.7. text :  Подскажите, вы звоните по личному или по деловому вопросу?
# SPEAKER_01: 222.2 - 224.0. text :  Скажите еще раз, пожалуйста.
# SPEAKER_01: 226.5 - 228.5. text :  А не могли бы вы повторить?
# SPEAKER_01: 230.7 - 233.4. text :  Я не расслышала, что вы сказали?
# SPEAKER_01: 235.6 - 239.1. text :  Я не расслышала, повторите, пожалуйста.
# SPEAKER_01: 241.2 - 242.6. text :  А повторите погромче.
# SPEAKER_01: 244.8 - 246.6. text :  Может быть передать абоненту, в какое время можно вам перезвонить?
# SPEAKER_01: 248.7 - 250.6. text :  Скажите еще раз, пожалуйста.
# SPEAKER_01: 252.7 - 254.8. text :  Извините, меня слышно?
# SPEAKER_01: 256.9 - 260.6. text :  Не расслышала, что вы сказали?
# SPEAKER_01: 262.8 - 264.2. text :  А может ли абонент связаться с вами по номеру, с которого вы звоните?
# SPEAKER_01: 266.4 - 269.1. text :  А повторите погромче.
# SPEAKER_01: 271.2 - 273.4. text :  Не расслышала, что вы сказали?
# SPEAKER_01: 275.5 - 277.3. text :  Извините, меня слышно?
# SPEAKER_01: 279.4 - 283.3. text :  Уточните, вы знакомы с абонентом или мне представить вас?
# SPEAKER_01: 285.5 - 286.9. text :  А повторите погромче.
# SPEAKER_01: 289.1 - 291.2. text :  А повторите погромче, пожалуйста.
# SPEAKER_01: 293.3 - 294.4. text :  Алло, вы тут?
# SPEAKER_01: 296.6 - 298.8. text :  Не расслышала, что вы сказали?
# SPEAKER_01: 300.9 - 304.6. text :  Подскажите, вы звоните по личному или по деловому вопросу?
# SPEAKER_01: 307.0 - 309.4. text :  Скажите погромче, я вас не услышала.
# SPEAKER_01: 311.5 - 313.4. text :  Извините, меня слышно?
# SPEAKER_01: 315.6 - 317.6. text :  А повторите погромче, пожалуйста.
# SPEAKER_01: 319.8 - 322.5. text :  Я не расслышала, повторите, пожалуйста.
# SPEAKER_00: 320.1 - 320.5. text :  Я не расслышала, повторите, пожалуйста.
# SPEAKER_01: 324.7 - 328.2. text :  Может быть передать абоненту, в какое время можно вам перезвонить?
# SPEAKER_01: 330.5 - 333.0. text :  Скажите погромче, я вас не услышала.
# SPEAKER_01: 335.1 - 336.9. text :  Скажите еще раз, пожалуйста.
# SPEAKER_01: 339.1 - 341.2. text :  А повторите погромче, пожалуйста.
# SPEAKER_01: 343.3 - 345.1. text :  Извините, меня слышно?
# SPEAKER_01: 347.2 - 350.9. text :  А может ли абонент связаться с вами по номеру, с которого вы звоните?
# SPEAKER_01: 353.1 - 355.2. text :  Не расслышала, что вы сказали?
# SPEAKER_01: 357.4 - 359.2. text :  Скажите еще раз, пожалуйста.
# 1

# %% [markdown]
# # Оценка диаризации

# %%
fully_transcribed_files = get_all_files(FULLY_TRANSCRIBED_FOLDER_PATH)
base_files = get_all_files(BASE_TRANSCRIBED_TEXT_PATH)
# Out:
# 261 files in the folder
# 204 files in the folder

# %%
import re
import pandas as pd

columns = ['Имя файла', 'Разница с эталоном']

df = pd.DataFrame(columns=columns)
counter = 0
for transcribed in fully_transcribed_files:
    base_file = None
    for search_base_file in base_files:
        if search_base_file['name'] ==  transcribed['name']:
              base_file = search_base_file
              break
    if base_file == None:
        # print(f'Не найден исходный файл для {transcribed["name"]}')
        continue

    base_file = read_file_text(base_file['id'], UTF8_ENCODING)
    base_file = re.split(r'\b\d{1,2}:\d{2}:\d{2}\b', base_file)
    base_file = list(map(lambda s: s.replace('\n', '').replace('\r', ''), base_file))
    base_file = [s for s in base_file if s != '']
    transcribed_json = read_file_text(transcribed['id'], WINDOWS_1251_ENCODING).replace('\\n', '').replace('\\\"', '\"')[1:-1].replace('  ', '')
    transcribed_data = json.loads(transcribed_json)

    transcribed_list = []

    prev_speaker = None
    text_to_join = ''
    segment_start_to_join = None

    diff = abs(len(base_file) - len(transcribed_data))
    result_row = {'Имя файла': transcribed['name'],
                  'Разница с эталоном': f'{diff}'}

    df = pd.concat([df, pd.DataFrame([result_row])], ignore_index=True)

# %%
df
mean_diff = df['Разница с эталоном'].astype(float).median()
print(f'Mean diff {mean_diff}')
df = df.sort_values(['Разница с эталоном'], ascending=False)
df

# %% [markdown]
# # Получение эмбеддингов

# %% [markdown]
# Основные классы для работы

# %%
import asyncio
import os
from typing import List, Dict

import numpy as np
from openai import OpenAI
from openai import AsyncOpenAI
from sklearn.preprocessing import StandardScaler
from umap import UMAP
import hdbscan
from sklearn.decomposition import PCA
from sklearn.preprocessing import normalize


class TextProcessor:
    def __init__(self, api_key: str = ""):
        self._client = AsyncOpenAI(api_key=api_key)
        self._embed_model = "text-embedding-3-small"
        self._chat_model =  "gpt-3.5-turbo"
        self.dimentions = 256
        self.chunk_size = 128

    async def get_text_embedding(self, text_list: List[str]) -> np.ndarray:

        for ind, text in enumerate(text_list):
            text = text.replace("\n", " ")
            if not text:
                text = 'other'
            text_list[ind] = text

        try:
            tasks = []
            for i in range(0, len(text_list), self.chunk_size):
                text_chunk = text_list[i:i + self.chunk_size]

                task = asyncio.create_task(self._client.embeddings.create(
                    input=text_chunk,
                    model=self._embed_model,
                    dimensions=self.dimentions,
                ))
                tasks.append(task)
            tasks_results = await asyncio.gather(*tasks)

            embeddings = []
            for result in tasks_results:
                for data in result.data:
                    embeddings.append(np.array(data.embedding))

        except Exception as e:
            print(e)
            return np.zeros(self.dimentions)  # TODO!!!
        return np.stack(embeddings, axis=0)

    async def get_text_completions(self, system_prompt: str, text_dict: Dict[str, str], return_json=False):
        for key, text in text_dict.items():
            if not text:
                print('Found empty text prompt for document!')
                text_dict[key] = 'empty'

        text_items = list(text_dict.items())
        text_ids = [item[0] for item in text_items]
        text_list = [item[1] for item in text_items]

        response_format = None
        if return_json:
            response_format = {"type": "json_object"}

        tasks = []
        for text in text_list:
            task = asyncio.create_task(self._client.chat.completions.create(
                model=self._chat_model,
                messages=[
                    {"role": "system", "content": system_prompt},
                    {"role": "user", "content": text}
                ],
                response_format=response_format,
            ))
            tasks.append(task)

        tasks_results = await asyncio.gather(*tasks)

        predictions = []
        for response in tasks_results:
            answer = ''
            for choice in response.choices:
                answer += choice.message.content
            predictions.append(answer)

        return {text_id: pred for text_id, pred in zip(text_ids, predictions)}


class DimentionReduction:

    def __init__(self):
        self.umap = UMAP(
            n_components=2,
            n_neighbors=5,
            min_dist=0.01,
            spread=4.0,
            metric='euclidean',
            random_state=42,
        )
        self.pca = PCA(n_components=2)
        self.scaler = StandardScaler()

    def apply(self, embeddings: np.ndarray) -> np.ndarray:
        embeddings = self.scaler.fit_transform(embeddings)

        if len(embeddings) < 10:
            return self.scaler.fit_transform(self.pca.fit_transform(embeddings))

        return self.scaler.fit_transform(self.umap.fit_transform(embeddings))


class ClustersReduction:
    """-1 значит точка выброс"""
    def __init__(self):
        self._hdb = hdbscan.HDBSCAN(
            min_samples=3,
            min_cluster_size=2,
            metric='euclidean',
            cluster_selection_epsilon=0.1,
        )

    def apply(self, embeddings: np.ndarray):
        embeddings = normalize(embeddings, norm='l2')
        model = self._hdb.fit(embeddings)
        return model.labels_

# %% [markdown]
# Основной процесс

# %%
# Класс для основного процесса
class MainProcessor:
    def __init__(self, api_key: str, folder_path: str):
        self.folder_path = folder_path
        self.text_processor = TextProcessor(api_key)
        self.dimension_reduction = DimentionReduction()
        self.clusters_reduction = ClustersReduction()

    def load_text_files(self) -> List[str]:
        text_files_content = []
        base_files = get_all_files(BASE_TRANSCRIBED_TEXT_PATH)
        for base_file in base_files:
            text_files_content.append(read_file_text(base_file['id'], UTF8_ENCODING))
        # for filename in os.listdir(self.folder_path):
        #     if filename.endswith('.txt'):
        #         file_path = os.path.join(self.folder_path, filename)
        #         try:
        #             with open(file_path, 'r', encoding='utf-8') as file:
        #                 content = file.read().strip()
        #                 if content:
        #                     text_files_content.append(content)
        #                 else:
        #                     print(f"Файл {filename} пуст и не будет обработан.")
        #         except Exception as e:
        #             print(f"Ошибка при чтении файла {filename}: {e}")

        print(f"Количество загруженных текстов: {len(text_files_content)}")
        return text_files_content


    async def process(self):
        text_data = self.load_text_files()

        if not text_data:
            print("Не найдено текстовых файлов в указанной папке.")
            return

        embeddings = await self.text_processor.get_text_embedding(text_data)

        if embeddings.size == 0 or embeddings.ndim != 2:
            print("Не удалось получить эмбеддинги или эмбеддинги имеют неправильную размерность.")
            return

        print(f"Количество полученных эмбеддингов: {embeddings.shape[0]}")

        reduced_embeddings = self.dimension_reduction.apply(embeddings)
        cluster_labels = self.clusters_reduction.apply(reduced_embeddings)

        print(f"Кластеры: {cluster_labels}")

        # Вывод кластеров и текстов
        cluster_results = {}
        for text, cluster in zip(text_data, cluster_labels):
            cluster_results.setdefault(cluster, []).append(text)

        print("Результаты кластеризации:")
        for cluster, texts in cluster_results.items():
            print(f"\nКластер {cluster}:")
            for text in texts:
                print(f"- {text[:100]}...")

# %% [markdown]
# Запуск процесса

# %%
async def main():
    api_key = API_KEY
    folder_path = BASE_TRANSCRIBED_TEXT_PATH[:-1]

    processor = MainProcessor(api_key, folder_path)
    await processor.process()

await main()
# Out:
# 138 files in the folder
# Количество загруженных текстов: 138
# Количество полученных эмбеддингов: 138
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/umap/umap_.py:1401: RuntimeWarning: divide by zero encountered in power
#   return 1.0 / (1.0 + a * x ** (2 * b))
# /usr/local/lib/python3.10/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# Кластеры: [ 6  4  2  6  0  4  5  0  8  4  6  3  4  1  6  6  1  0  1  3  7 -1  0  7
#   4  6  8  3  4  4  3  1  4  6  4 -1  3  4  3  4  4  1  6  8  4  1  1  0
#   4  4  0  1  1  4  4  2  3  6  4  1  2  3  4  0 -1  0  0 -1  3  4  1  1
#   2  5  4 -1  5  4  0  1  4  4  4  6  4 -1  5  8  6  4  4  6  0  6  1  1
#   6  4  6  6 -1  6  8  1  8  3  2  4 -1  4  6  2  5  6  4  4  8  4  0 -1
#   4  8  0  1  3  8  8  6  6  4  4  1  1  8  4  4 -1  3]
# Результаты кластеризации:
#
# Кластер 6:
# - ['  SPEAKER_00: ', '  SPEAKER_04:  Доброе утро, студия Комакс, не слышала.', '  SPEAKER_00:  Продолж...
# - ['  SPEAKER_00:  Пусть я глубокий, здравствуйте.']...
# - ['  SPEAKER_01:  Добрый вечер, студия Гоу Боксинг. Меня зовут Анна. Чем могу помочь?', '  SPEAKER_00...
# - ['  SPEAKER_00:  Спасибо.', '  SPEAKER_01:  Администратор Гоу-Боксинг, добрый день, слушаю вас.', ' ...
# - ['  SPEAKER_03: ', '  SPEAKER_02:  Здравствуйте, студия Гоу Боксинг, слушаю вас. Добрый вечер. Можно...
# - ['  SPEAKER_02:  Добрый день, студия Глобоксинг, слушаю вас.', '  SPEAKER_00:  Здравствуйте, я вот к...
# - ['  SPEAKER_01:  Здравствуйте!', '  SPEAKER_00:  Да, добрый день. А можете, пожалуйста, охране позво...
# - ['  SPEAKER_00:  Голубок, Семен Александр Елизавета, слушаю вас.', '  SPEAKER_01:  Здравствуйте, отк...
# - ['  SPEAKER_00:  Добрый день, Гомбоксик. Меня зовут Анна. Чем могу помочь?', '  SPEAKER_03:  Добрый ...
# - ['  SPEAKER_00: ', '  SPEAKER_02:  Добрый день, студия Гобоксинг, слушаю вас.', '  SPEAKER_00:  Да, ...
# - ['  SPEAKER_01:  Продолжение следует...', '  SPEAKER_00:  Тудяго Бокс, здравствуйте.', '  SPEAKER_01...
# - ['  SPEAKER_00:  студия голубов здравствуйте. Здравствуйте, откроется шлагбаум 937 номер машины? 937...
# - ['  SPEAKER_00:  Добрый вечер, судья Глубоксинг, слушаю вас.', '  SPEAKER_03:  Добрый, может нам, по...
# - ['  SPEAKER_03:  Здравствуйте, студия Губок, не слушаю вас.', '  SPEAKER_01:  Здравствуйте, девушка....
# - ['  SPEAKER_02:  Спасибо.', '  SPEAKER_01:  Доброе утро, студия Кубок, слушаю вас.', '  SPEAKER_00: ...
# - ['  SPEAKER_00:  Здравствуйте, студия Гоу Боксинг слушаю вас. Добрый вечер, можете на охрану сказать...
# - ['  SPEAKER_00:  Добрый день, судья Кубокс, не слышу вас.', '  SPEAKER_01:  Добрый вечер. Хотите при...
# - ['  SPEAKER_02: ', '  SPEAKER_01:  Здравствуйте.', '  SPEAKER_02:  Продолжение следует...', '  SPEAK...
# - ['  SPEAKER_02: ', '  SPEAKER_01:  А?', '  SPEAKER_00:  Вечером можно было бы...', '  SPEAKER_01:  С...
# - ['  SPEAKER_01: ', '  SPEAKER_00:  Добрый вечер. Алло. Здравствуйте. Нашла ваш номер во Вконтакте. П...
# - ['  SPEAKER_02:  Тут я глубоко не тратил.', '  SPEAKER_03:  Спасибо.', '  SPEAKER_00:  Здравствуйте,...
#
# Кластер 4:
# - ['  SPEAKER_01:  Добрый день, Голбоксинг. Меня зовут Анна. Чем могу помочь?', '  SPEAKER_00:  Здравс...
# - ['  SPEAKER_01:  ЗВОНОК В ДВЕРЬ Студия GoBoking. Здравствуйте, меня зовут Илья.', '  SPEAKER_00:  Зд...
# - ['  SPEAKER_01: ', '  SPEAKER_00:  Добрый день, слушаю вас.', '  SPEAKER_01:  Алло, здравствуйте. Хо...
# - ['  SPEAKER_00:  Добрый вечер, студия бокса, слушаю вас. Скажите, у вас в клубе только бокс или есть...
# - ['  SPEAKER_01:  Телефон звонит Телефон звонит Телефон звонит Здравствуйте, меня зовут Илья Здравств...
# - ['  SPEAKER_00:  Добрый день, был Боксинг, слушаю вас.', '  SPEAKER_01:  Алло, здравствуйте. Подскаж...
# - ['  SPEAKER_01:  Здравствуйте, студия Гоблоксинг, слушаю вас.', '  SPEAKER_00:  Здравствуйте. А подс...
# - ['  SPEAKER_00:  Гоу-бокс, на минуту. Резолета, слушаю вас. Резолета, добрый день. Вот связка что-то...
# - ['  SPEAKER_00:  Добрый день, студия Го Бокс. Алло, здравствуйте. Вот я хотела с вами проконсультиро...
# - ['  SPEAKER_01:  Продолжение следует...', '  SPEAKER_03:  Спасибо.', '  SPEAKER_01:  Слушаю вас.', '...
# - ['  SPEAKER_01:  Здравствуйте, студия Гоу Боксинг, слушаю вас. Здравствуйте, хочу к вам записаться в...
# - ['  SPEAKER_01:  Ура!', '  SPEAKER_00:  Это Диагобоксинг, здравствуйте, меня зовут Илья.', '  SPEAKE...
# - ['  SPEAKER_00:  Голбоксинг, смена вулкана, чесноку помочь.', '  SPEAKER_01:  Анна, добрый день. Под...
# - ['  SPEAKER_00:  Добрый день, судья Голубок, не слушаю вас.', '  SPEAKER_01:  Здравствуйте, меня зов...
# - ['  SPEAKER_00:  Добрый день, студентка, вовсе услышала.', '  SPEAKER_01:  Да, здравствуйте. Скажите...
# - ['  SPEAKER_00:  Людмила Боксина, добрый день, слушаю вас.', '  SPEAKER_01:  Здравствуйте. Подскажит...
# - ['  SPEAKER_01:  Рассказ у вас. Сырье по боксу, добрый вечер, слушаю вас.', '  SPEAKER_02:  Добрый в...
# - ['  SPEAKER_01: ', '  SPEAKER_00:  Продолжение следует...', '  SPEAKER_01:  Добрый день, студия Кубо...
# - ['  SPEAKER_01:  Студия Гоблоксинг. Здравствуйте, меня зовут Илья.', '  SPEAKER_00:  Здравствуйте, Л...
# - ['  SPEAKER_00:  Добрый день.', '  SPEAKER_01:  Солом.', '  SPEAKER_00:  Добрый день. Хотела бы уточ...
# - ['  SPEAKER_00:  Добрый день, меня зовут Анна, могу помочь?', '  SPEAKER_01:  Добрый день, хотел бы ...
# - ['  SPEAKER_00:  Добрый день, студия Гобоксинг, слушаю вас. Здравствуйте, скажите, пожалуйста, у вас...
# - ['  SPEAKER_00:  Сетевый бокс. Я слушаю вас.', '  SPEAKER_01:  Добрый вечер. Правильно понимаю, что ...
# - ['  SPEAKER_00:  Здравствуйте, девушка. Подскажите, пожалуйста, в каком формате проходят занятия по ...
# - ['  SPEAKER_00:  Добрый день, студия Голбокс, не слышала вас. Здравствуйте, я бы хотела узнать про т...
# - ['  SPEAKER_00:  Добрый день, нашла вас на Тегисе. Скажите, на пробную тренировку можно сегодня запи...
# - ['  SPEAKER_00: ', '  SPEAKER_01: ', '  SPEAKER_00:  Здравствуйте! Я сегодня к вам впервые записалас...
# - ['  SPEAKER_00:  Здравствуйте, студия Гобоксинг.', '  SPEAKER_01:  Редактор субтитров А.Семкин Корре...
# - ['  SPEAKER_00:  Добрый день, Светлана. Меня зовут Анна. Чем могу помочь? Здравствуйте. Скажите, это...
# - ['  SPEAKER_01:  Добрый день, Голл Моксинг, меня зовут Анна, чем могу помочь?', '  SPEAKER_00:  Анна...
# - ['  SPEAKER_00:  Добрый день, студия GoVoxing, меня зовут Анна, что могу помочь?', '  SPEAKER_01:  Д...
# - ['  SPEAKER_00:  Продолжение следует...', '  SPEAKER_01:  Добрый день, Голубоксинг, меня зовут Анна....
# - ['  SPEAKER_03:  Добрый день, судья Клубов.', '  SPEAKER_00:  Да, скажите, подскажите, пожалуйста, с...
# - ['  SPEAKER_00:  Здравствуйте. Губок не слышу вас. А, здравствуйте. Интересует услуга три тренировки...
# - ['  SPEAKER_01:  Добрый день, студия GoBoxing. Меня зовут Анна, я могу помочь?', '  SPEAKER_00:  Про...
# - ['  SPEAKER_01:  Добрый день, судья Голбокс, не слышал вас.', '  SPEAKER_00:  Алло, здрасте, это фит...
# - ['  SPEAKER_01:  Добрый вечер, Тодя Голобокс, слушаю вас.', '  SPEAKER_00:  Здравствуйте, скажите, п...
# - ['  SPEAKER_01:  Тренировки в атмосфере, точнее, в центре Москвы. Как тебе? Go Boxing, Елизавета, сл...
# - ['  SPEAKER_00:  Добрый день, студия «Гоу Боксинг», Олег.', '  SPEAKER_01:  Здравствуйте, Олег. Скаж...
#
# Кластер 2:
# - ['  SPEAKER_00:  Добрый день, Глобоксинг. Меня зовут Анна. Чем могу помочь?', '  SPEAKER_02:  Здравс...
# - ['  SPEAKER_01: ', '  SPEAKER_04:  Тут я глубоко.', '  SPEAKER_00:  Никладим.', '  SPEAKER_02:  Алло...
# - ['  SPEAKER_00:  Продолжение следует...', '  SPEAKER_01:  Друзья, Голбоксинг, добрый день, слушаю ва...
# - ['  SPEAKER_00:  Добрый день, студентка, Глобоксинг.', '  SPEAKER_01:  Продолжение следует...']...
# - ['  SPEAKER_01: ', '  SPEAKER_00:  Я боксер. Здравствуйте.', '  SPEAKER_01:  Продолжение следует...'...
# - ['  SPEAKER_01:  Добрый день, Гогл Боксинг. Меня зовут Анна Чамова.', '  SPEAKER_00:  Добрый день, з...
#
# Кластер 0:
# - ['  SPEAKER_01:  Дядя Гобоксин, добрый день, слушаю вас.', '  SPEAKER_02:  Алло, здравствуйте. Мы аб...
# - ['  SPEAKER_02:  Добрый день, Голдбоксинг, меня зовут Анна, чем могу помочь?', '  SPEAKER_01:  Алло,...
# - ['  SPEAKER_01:  Добрый день, с вами Голбоксинг, меня зовут Анна, чем могу помочь?', '  SPEAKER_00: ...
# - ['  SPEAKER_01:  Добрый день, студия Гоу Боксинг. Меня зовут Анна, я могу помочь? Здравствуйте, а мн...
# - ['  SPEAKER_02: ', '  SPEAKER_01:  Здравствуйте, студия Городской.', '  SPEAKER_00:  Добрый день, ме...
# - ['  SPEAKER_02:  Добрый день, студия Голубоксис, меня зовут Анна.', '  SPEAKER_01:  Добрый день, мен...
# - ['  SPEAKER_00:  Субтитры сделал DimaTorzok', '  SPEAKER_01:  Субтитры создавал DimaTorzok', '  SPEA...
# - ['  SPEAKER_01:  Прошу прощения, добрый день, Голбоксинг. Меня зовут Анна.', '  SPEAKER_00:  Здрасте...
# - ['  SPEAKER_00:  Добрый день, Бомбоксинг, меня зовут Анна, чем могу помочь?', '  SPEAKER_06:  Добрый...
# - ['  SPEAKER_00:  Добрый день, Бомбоксинг, меня зовут Анна, чем могу помочь? Добрый день, меня заинте...
# - ['  SPEAKER_01:  Доброе утро.', '  SPEAKER_02:  Раскрутка гобоксов. Добрый день, меня зовут Александ...
# - ['  SPEAKER_02:  Продолжение следует...', '  SPEAKER_01:  Здравствуйте, Диагон Боксинг. Здравствуйте...
# - ['  SPEAKER_00:  Добрый день, студия «Глубок»! Не слушаю вас.', '  SPEAKER_03:  Алло, здравствуйте. ...
#
# Кластер 5:
# - ['  SPEAKER_00:  Добрый день, студия Гоу Боксинг. Меня зовут Анна. Чем могу помочь?', '  SPEAKER_02:...
# - ['  SPEAKER_01:  Добрый вечер, Голбоксер Смитут Анни.', '  SPEAKER_00:  О, здравствуйте! Я вот никак...
# - ['  SPEAKER_00:  Здравствуйте, студия Гоу Боксинг, слушаю вас.', '  SPEAKER_01:  Да, здравствуйте ещ...
# - ['  SPEAKER_00:  Здравствуйте, студия Гоу Боксинг, слушаю вас.', '  SPEAKER_01:  Здравствуйте, я хот...
# - ['  SPEAKER_01:  Добрый день, Голубкинг. Меня зовут Анна. Я хочу немного помочь.', '  SPEAKER_00:  З...
#
# Кластер 8:
# - ['  SPEAKER_01:  Это будет очень здравствуйте, дорогие друзья.', '  SPEAKER_00:  Меня зовут Илья. До...
# - ['  SPEAKER_01:  Студия Бокса, добрый вечер, слушаю вас.', '  SPEAKER_00:  Добрый вечер. Меня задави...
# - ['  SPEAKER_01:  Спасибо.', '  SPEAKER_00:  Добрый день, меня зовут Виктория. Подскажите, а Владимир...
# - ['  SPEAKER_00:  Ну, понял. Ну, подпишись куда-нибудь, ты что-то здесь молодец там. Добрый день, мен...
# - ['  SPEAKER_00:  Добрый день, студия Гоу Бокс, слушаю вас. Да, кстати, я хотела уточнить, я, в общем...
# - ['  SPEAKER_00:  Studio Go Boxing. Здравствуйте, меня зовут Илья.', '  SPEAKER_02:  Да, здравствуйте...
# - ['  SPEAKER_02:  студия GO BOXING, здравствуйте.', '  SPEAKER_00:  Здравствуйте. Илья сегодня на тре...
# - ['  SPEAKER_01:  Здравствуйте, Сутябокс, услышалась.', '  SPEAKER_00:  Спасибо.', '  SPEAKER_01:  До...
# - ['  SPEAKER_00:  Спасибо.', '  SPEAKER_01:  Здравствуйте.', '  SPEAKER_00:  Добрый день, меня зовут ...
# - ['  SPEAKER_01:  Я не päädобался, правда понимали ... Это ничего неiam', '  SPEAKER_00:  Добрый день...
# - ['  SPEAKER_00:  Добрый день, меня зовут Виктория. Скажите, а Владимира могу услышать руководителя? ...
#
# Кластер 3:
# - ['  SPEAKER_00:  Добрый день, Голубоксер. Меня зовут Анна. Чем могу помочь?', '  SPEAKER_01:  Здравс...
# - ['  SPEAKER_02:  Садя Глобоксинг, добрый день, слушаю вас.', '  SPEAKER_00:  Доброе утро, девушка. А...
# - ['  SPEAKER_01:  Go Boxing! Елизавета, слушаю вас.', '  SPEAKER_00:  О, здравствуйте, меня зовут Фан...
# - ['  SPEAKER_00: ', '  SPEAKER_01: ', '  SPEAKER_00:  Продолжение следует...', '  SPEAKER_01: ', '  S...
# - ['  SPEAKER_01:  Здравствуйте, студия Кубоксинг, слушаю вас.', '  SPEAKER_00:  Скажите, а вы знаете,...
# - ['  SPEAKER_00:  Здравствуйте, я тут Илья. Здравствуйте.', '  SPEAKER_01:  Угу.', '  SPEAKER_00:  Ме...
# - ['  SPEAKER_02:  Добрый день, был Боксинг, меня зовут Анна Чумакова.', '  SPEAKER_01:  Добрый день. ...
# - ['  SPEAKER_01:  Здравствуйте, слушаю вас. Алло, здравствуйте. То, что Ира вас приспокоит, у меня та...
# - ['  SPEAKER_00:  Добрый день, студия Голубок. Меня зовут Анна. Чем могу помочь?', '  SPEAKER_01:  Зд...
# - ['  SPEAKER_00:  Здравствуйте, студия Гобоксинг слушаю вас.', '  SPEAKER_01:  Здравствуйте, меня зов...
# - ['  SPEAKER_00:  Пойду глубоким, здравствуйте.', '  SPEAKER_01:  Подскажите, пожалуйста, у вас возмо...
# - ['  SPEAKER_00:  Добрый день, Голубоксинг, меня зовут Анна, чем могу помочь? Алло, добрый день, меня...
#
# Кластер 1:
# - ['  SPEAKER_02: ', '  SPEAKER_01:  Продолжение следует...', '  SPEAKER_02:  Спасибо.', '  SPEAKER_01...
# - ['  SPEAKER_00:  Добрый день, Губоксинг. Меня зовут Анна. Чем могу помочь?', '  SPEAKER_01:  Аня, кс...
# - ['  SPEAKER_00:  Добрый день, студия Глобоксинг, слушаю вас. Здравствуйте. Вот скажите, я на завтра ...
# - ['  SPEAKER_00:  Добрый день.', '  SPEAKER_02:  Спасибо.', '  SPEAKER_00: ', '  SPEAKER_02: ', '  SP...
# - ['  SPEAKER_00:  Добрый день, студия Гоу Боксинг, слушаю вас.', '  SPEAKER_01:  Здравствуйте. Хотела...
# - ['  SPEAKER_00:  Здравствуйте, студия Гоу Боксинг, слушаю вас. Здравствуйте, подскажите, пожалуйста,...
# - ['  SPEAKER_00:  Studio Go Boxing. Здравствуйте, меня зовут Илья.', '  SPEAKER_01:  Илья, здравствуй...
# - ['  SPEAKER_01:  Здравствуйте, меня зовут Илья.', '  SPEAKER_00:  Да, доброго дня. Подскажите, пожал...
# - ['  SPEAKER_00:  Добрый день, студия Голлбоксинг, слушаю вас. Да, девка, здравствуйте, с вами, навер...
# - ['  SPEAKER_00:  Здравствуйте, студия Блобоксинг, слушаю вас.', '  SPEAKER_01:  Здравствуйте, подска...
# - ['  SPEAKER_00:  Продолжение следует...', '  SPEAKER_01:  Здравствуйте, Сергей Губок, не слышу вас.'...
# - ['  SPEAKER_00:  Здравствуйте, студия Гобоксинг, слушаю вас.', '  SPEAKER_02:  Здравствуйте, расскаж...
# - ['  SPEAKER_01:  Studio Go Boxing, здравствуйте.', '  SPEAKER_00:  Алло, здравствуйте, это Илья?', '...
# - ['  SPEAKER_01:  Я бы бог с ним наблюдать зашел.', '  SPEAKER_00:  Добрый день. Мне интересует трени...
# - ['  SPEAKER_02:  Продолжение следует...', '  SPEAKER_01:  Добрый день, слушаю вас. Да, добрый день. ...
# - ['  SPEAKER_01:  Здравствуйте, студия Глубокий, услышалось.', '  SPEAKER_00:  Здравствуйте. Я вот за...
# - ['  SPEAKER_00:  Добрый день, слушаю вас. Добрый день, подскажите, пожалуйста, я хотела к вам записа...
# - ['  SPEAKER_00:  Да. Сигарет Гоу Боксинг, здравствуйте. Здрасте. Я, знаете, мне зовут Катя, я что хо...
# - ['  SPEAKER_00:  Гоу-боксинг, администратор Елизавета, слушаю вас. Здравствуйте, девушка. Я вот сейч...
#
# Кластер 7:
# - ['  SPEAKER_01:  Да, вы осуществляете.', '  SPEAKER_00:  Да, извините, Илья, да, песня, чтобы с вами...
# - ['  SPEAKER_03:  Спасибо.', '  SPEAKER_01:  Привет, я Гобоксинг, здравствуйте, меня зовут Илья.', ' ...
#
# Кластер -1:
# - ['  SPEAKER_00:  Телефон звонит Студия Гомбоксинг, здравствуйте, меня зовут Илья', '  SPEAKER_01:  З...
# - ['  SPEAKER_01:  Добрый день, студия Кубокс, я слушаю вас.', '  SPEAKER_00:  Да, здравствуйте, девуш...
# - ['  SPEAKER_00:  Голбоксинг, Елизавета, слушаю вас.', '  SPEAKER_01:  Алло, здравствуйте, Елизавета,...
# - ['  SPEAKER_02:  Слушаю вас.', '  SPEAKER_00:  Да, да.', '  SPEAKER_00:  Да, здравствуйте. Девушка, ...
# - ['  SPEAKER_00:  Добрый день, студия Голубокс, наслушаю вас. Алло, здравствуйте. Скажите, пожалуйста...
# - ['  SPEAKER_00:  Телефон звонит Студия GoBoxing, здравствуйте, я Закалья', '  SPEAKER_01:  Здравству...
# - ['  SPEAKER_00:  студия GoBlocking. Здравствуйте, меня зовут Илья.', '  SPEAKER_01:  Да, здравствуйт...
# - ['  SPEAKER_01:  Спасибо.', '  SPEAKER_04:  Продолжение следует...', '  SPEAKER_01:  Добрый день, бы...
# - ['  SPEAKER_02:  Пойдем в Гобоксинг. Здравствуйте.', '  SPEAKER_01:  Да, добрый день. Не подскажите,...
# - ['  SPEAKER_00:  Доброе утро, студия Глубок.', '  SPEAKER_02:  Продолжение следует...', '  SPEAKER_0...
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %% [markdown]
# # Аналитика по темам групп

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score, accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sentence_transformers import SentenceTransformer
import matplotlib.pyplot as plt
import seaborn as sns
import re

def clean_text(text):
    # Удаляем префиксы "1. ", "2. ", "3. "
    text = re.sub(r'^\d+\.\s+', '', text)
    # Удаляем все, что идет после "-transcri..."
    text = re.sub(r'-transcri.*', '', text)
    return text

df = df_input.copy()

df['Тема'] = df['Тема'].apply(clean_text)
df['Краткая суть'] = df['Краткая суть'].fillna('').apply(clean_text)
df['Очень краткая суть'] = df['Очень краткая суть'].fillna('').apply(clean_text)
df['dialogue'] = df['Тема']

model = SentenceTransformer('all-MiniLM-L6-v2')
X_embeddings = model.encode(df['dialogue'], show_progress_bar=True)

silhouette_scores = []
K = range(2, 10)
for k in K:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_embeddings)
    labels = kmeans.labels_
    silhouette_avg = silhouette_score(X_embeddings, labels)
    silhouette_scores.append(silhouette_avg)

plt.figure(figsize=(8, 4))
plt.plot(K, silhouette_scores, 'bx-')
plt.xlabel('Количество кластеров')
plt.ylabel('Средний силуэтный коэффициент')
plt.title('Силуэтный анализ для определения оптимального числа кластеров')
plt.show()

# Определение оптимального количества кластеров
optimal_k = K[silhouette_scores.index(max(silhouette_scores))]
print(f"Оптимальное количество кластеров: {optimal_k}")

# Кластеризация с использованием KMeans с оптимальным количеством кластеров
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
kmeans.fit(X_embeddings)
df['initial_cluster'] = kmeans.labels_

# Используем кластеры как метки для классификации
X_train, X_test, y_train, y_test = train_test_split(X_embeddings, df['initial_cluster'], test_size=0.3, random_state=42)

classifiers = {
    'LogisticRegression': LogisticRegression(max_iter=1000),
    'RandomForestClassifier': RandomForestClassifier(n_estimators=100, random_state=42),
    'GradientBoostingClassifier': GradientBoostingClassifier(n_estimators=100, random_state=42),
    'MLPClassifier': MLPClassifier(max_iter=1000, random_state=42)
}

group_themes = {}
for group_num in set(df['final_group']):
    group_texts = df[df['final_group'] == group_num]['dialogue'].tolist()
    vectorizer_group = TfidfVectorizer()
    X_group = vectorizer_group.fit_transform(group_texts)
    feature_names = vectorizer_group.get_feature_names_out()
    tfidf_scores = X_group.sum(axis=0).A1
    sorted_items = sorted(zip(tfidf_scores, feature_names), reverse=True)

    top_words = [word for _, word in sorted_items[:3]]
    theme_name = " | ".join(top_words)
    group_themes[group_num] = theme_name

    top_words = sorted_items[:10]
    words, scores = zip(*top_words)

    plt.figure(figsize=(10, 5))
    sns.barplot(x=scores, y=words, palette="coolwarm")
    plt.title(f'Топ 10 ключевых слов для группы {group_num} ({group_themes[group_num]})')
    plt.xlabel('TF-IDF балл')
    plt.ylabel('Ключевые слова')
    plt.show()

    print(f"\nСодержимое группы {group_num} ({group_themes[group_num]}):")
    group_df = df[df['final_group'] == group_num]
    print(group_df[['dialogue']])

df['Тема группы'] = df['final_group'].map(group_themes)

plt.figure(figsize=(10, 6))
sns.barplot(x=df['Тема группы'].value_counts().index, y=df['Тема группы'].value_counts().values, palette="viridis")
plt.title('Распределение данных по финальным группам (с названиями тем)')
plt.xlabel('Название группы')
plt.ylabel('Количество диалогов')
plt.xticks(rotation=45)
plt.show()

pca = PCA(n_components=2)
principal_components = pca.fit_transform(X_embeddings)
plt.figure(figsize=(10, 7))
sns.scatterplot(x=principal_components[:, 0], y=principal_components[:, 1], hue=df['Тема группы'], palette="viridis", s=100, legend="full")
plt.title("Финальные группы данных с названиями тем")
plt.xlabel("Главная компонента 1")
plt.ylabel("Главная компонента 2")
plt.legend(title='Тема группы', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

print("\nАналитика по темам групп:")
for group_num, theme_name in group_themes.items():
    count_in_group = df[df['final_group'] == group_num].shape[0]
    print(f"Тема: {theme_name}")
    print(f"Количество диалогов: {count_in_group}")
    print(f"Ключевые слова: {', '.join([word for _, word in sorted_items[:10]])}")
    print('-' * 40)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-aef3e8dd3440> in <cell line: 22>()
#      20     return text
#      21
# ---> 22 df = df_input.copy()
#      23
#      24 df['Тема'] = df['Тема'].apply(clean_text)
#
# NameError: name 'df_input' is not defined

# %%
# !pip install hdbscan
# Out:
# Collecting hdbscan
#   Downloading hdbscan-0.8.40-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (15 kB)
# Requirement already satisfied: numpy<3,>=1.20 in /usr/local/lib/python3.10/dist-packages (from hdbscan) (1.26.4)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.20 in /usr/local/lib/python3.10/dist-packages (from hdbscan) (1.6.0)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20->hdbscan) (3.5.0)
# Downloading hdbscan-0.8.40-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 20.9 MB/s eta 0:00:00
# Installing collected packages: hdbscan
# Successfully installed hdbscan-0.8.40
